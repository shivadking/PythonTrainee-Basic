# %% [markdown]
# # Flow Control

# %% [markdown]
# # Conditional Statements

# %% [markdown]
# ## 1. If statement
#         Decision making is required when we want to execute a code only if a certain condition is satisfied.

# %%
from IPython.display import Image
Image(filename='images/if_statement_flow_diagram.jpg')

# %% [markdown]
# #### Example

# %%
flag = True
if flag==True:
    print("Welcome")
    print("To")
    print("BeginnersBook.com")
# Out:
# Welcome
# To
# BeginnersBook.com

# %%
flag = False
if flag==True:
    print("Welcome")
    print("To")
    print("BeginnersBook.com")
print("Bye")
# Out:
# Bye

# %% [markdown]
# ### Short Hand If

# %%
a=5
b=2
if a > b: print("a is greater than b")
# Out:
# a is greater than b

# %% [markdown]
# ## 2. If..else
#         else -> The else keyword catches anything which isn't caught by the preceding conditions.

# %%
from IPython.display import Image
Image(filename='images/If_else_flow_diagram-1.jpg')

# %% [markdown]
# #### Example

# %%
num = 22
if num % 2 == 0:
    print("Even Number")
else:
    print("Odd Number")
# Out:
# Even Number

# %%
num = 25
if num % 2 == 0:
    print("Even Number")
else:
    print("Odd Number")
# Out:
# Odd Number

# %% [markdown]
# ### Short Hand If ... Else

# %%
a = 2
b = 330
print("A") if a > b else print("B")
# Out:
# B

# %%
num = 22
print("Even Number") if num % 2 == 0 else print("Odd Number")
# Out:
# Even Number

# %% [markdown]
# ## 3. if..elif..else
#     elif -> The elif keyword is pythons way of saying "if the previous conditions were not true, then try this condition".

# %%
num = 1122
if 9 < num < 99:
    print("Two digit number")
elif 99 < num < 999:
    print("Three digit number")
elif 999 < num < 9999:
    print("Four digit number")
else:
    print("number is <= 9 or >= 9999")
# Out:
# Four digit number

# %% [markdown]
# ## 4. Nested If
#         You can have if statements inside if statements, this is called nested if statements.

# %%
x = 11

if x > 10:
  print("Above ten,")
  if x > 20:
    print("and also above 20!")
  else:
    print("but not above 20.")
# Out:
# Above ten,
# but not above 20.

# %% [markdown]
# # Python Loops
#     Python has two primitive loop commands:
#
#     while loops
#     for loops

# %% [markdown]
# ## 1. The while Loop
#         With the while loop we can execute a set of statements as long as a condition is true.

# %%
from IPython.display import Image
Image(filename='images/whileLoopFlowchart.jpg')

# %% [markdown]
# ### Syntax of while loop

# %% [markdown]
# while condition:
#     #body_of_while

# %% [markdown]
# ### Print i as long as i is less than 6:

# %%
i = 1
while i < 6:
  print(i)
  i += 1 # i = i+1
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# ### While loop with else
#         while loops can also have an optional else block.
#         The else part is executed if the condition in the while loop evaluates to False.

# %%
'''Example to illustrate
the use of else statement
with the while loop'''

counter = 0

while counter < 3:
    print("Inside loop")
    counter = counter + 1
else:
    print("Inside else")
# Out:
# Inside loop
# Inside loop
# Inside loop
# Inside else

# %% [markdown]
# #### The while loop can be terminated with a break statement. In such cases, the else part is ignored. Hence, a while loop's else part runs if no break occurs and the condition is false.

# %%
'''Example to illustrate
the use of else statement
with the while loop'''

counter = 0

while counter < 3:
    print("Inside loop")
    counter = counter + 1
    if counter == 2:
        break
else:
    print("Inside else")
# Out:
# Inside loop
# Inside loop

# %% [markdown]
# ## 2. Python For Loops
#        A for loop is used for iterating over a sequence (that is either a list, a tuple, a dictionary, a set, or a string).

# %%
from IPython.display import Image
Image(filename='images/forLoop.jpg')

# %% [markdown]
# ### Syntax of For loop in Python

# %% [raw]
# for <variable> in <sequence>:
#    # body_of_loop that has set of statements
#    # which requires repeated execution

# %% [raw]
# Here <variable> is a variable that is used for iterating over a <sequence>.
# On every iteration it takes the next value from <sequence>  until the end of sequence is reached.

# %%
fruits = ["apple", "banana", "cherry"]
for x in fruits:
  print(x)
# Out:
# apple
# banana
# cherry

# %% [markdown]
# ### for loop with else
#         A for loop can have an optional else block as well. The else part is executed if the items in the sequence used in for loop exhausts.

# %%
digits = [0, 1, 5]

for i in digits:
    print(i)
else:
    print("No items left.")
# Out:
# 0
# 1
# 5
# No items left.

# %% [markdown]
# #### The break keyword can be used to stop a for loop. In such cases, the else part is ignored.

# %%
digits = [0, 1, 5]

for i in digits:
    print(i)
    if i == 1:
        break
else:
    print("No items left.")
# Out:
# 0
# 1

# %% [markdown]
# ## Break statement
#         The break statement terminates the loop containing it. Control of the program flows to the statement immediately after the body of the loop.
#
#         If the break statement is inside a nested loop (loop inside another loop), the break statement will terminate the innermost loop.

# %%
from IPython.display import Image
Image(filename='images/Break-statement-python.jpg')

# %%
# Use of break statement inside the loop

for val in "string":
    if val == "i":
        break
    print(val)

print("The end")
# Out:
# s
# t
# r
# The end

# %% [markdown]
# ## Continue Statement
#         The continue statement is used to skip the rest of the code inside a loop for the current iteration only. Loop does not terminate but continues on with the next iteration.

# %%
from IPython.display import Image
Image(filename='images/continue-statement-flowchart.jpg')

# %%
# Program to show the use of continue statement inside loops

for val in "string":
    if val == "i" or val=="t":
        continue
    print(val)

print("The end")
# Out:
# s
# r
# n
# g
# The end

# %% [markdown]
# ## Pass Statement
#         In Python programming, the pass statement is a null statement. The difference between a comment and a pass statement in Python is that while the interpreter ignores a comment entirely, pass is not ignored.
#
#         However, nothing happens when the pass is executed. It results in no operation (NOP).

# %% [markdown]
# Purpose
#
# Suppose we have a loop or a function that is not implemented yet, but we want to implement it in the future. They cannot have an empty body. The interpreter would give an error. So, we use the pass statement to construct a body that does nothing.

# %%
'''pass is just a placeholder for
functionality to be added later.'''
sequence = {'p', 'a', 's', 's'}
for val in sequence:
    pass

# %%
def function(args):
    pass

# %%
class Example:
    pass
